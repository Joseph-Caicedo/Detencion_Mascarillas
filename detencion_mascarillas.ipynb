# %% [markdown]
# <a href="https://colab.research.google.com/github/Joseph-Caicedo/Detencion_Mascarillas/blob/main/detencion_mascarillas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Conjunto de datos**

# %% [markdown]
# Se carga el conjunto de datos del siguiente repositorio:

# %%
# !git clone https://github.com/Joseph-Caicedo/Detenccion_Mascarillas.git
# Out:
# Cloning into 'Detenccion_Mascarillas'...
# remote: Enumerating objects: 2959, done.
# remote: Total 2959 (delta 0), reused 0 (delta 0), pack-reused 2959
# Receiving objects: 100% (2959/2959), 228.43 MiB | 38.73 MiB/s, done.
# Resolving deltas: 100% (94/94), done.
# Checking out files: 100% (5209/5209), done.

# %% [markdown]
# **Nota: La mayor parte del conjunto de datos se obtiene del repositorio ["observations"](https://github.com/prajnasb/observations.git) que es propiedad de [prajnasb](https://github.com/prajnasb) y  de ["MaskDetection"](https://github.com/DavidReveloLuna/MaskDetection.git) que es propiedad de [David Revelo Luna](https://github.com/DavidReveloLuna)**

# %% [markdown]
# Se observa el contenido del directorio "Detenccion_Mascarillas"

# %%
# !ls Detenccion_Mascarillas
# Out:
# Data_1			      mask_classifier_2.py  model_2.tflite
# Data_2			      mask_classifier.py    model_3.tflite
# detenccion_mascarillas.ipynb  model_1.tflite	    README.md

# %% [markdown]
# Se observa el contenido del dirctorio "Data_2"

# %%
# !ls Detenccion_Mascarillas/Data_2/
# Out:
# with_mask  without_mask

# %% [markdown]
# Se guarda la siguiente ruta:

# %%
data_path = 'Detenccion_Mascarillas/Data_2/'

# %% [markdown]
# Se visualizan los contenidos de los directorios del conjunto de datos

# %%
import os

data_dir = os.path.join(data_path)

with_mask_dir = os.path.join(data_dir, 'with_mask')
without_mask_dir = os.path.join(data_dir, 'without_mask')

with_mask_fnames = os.listdir( with_mask_dir )
without_mask_fnames = os.listdir( without_mask_dir )

print(with_mask_fnames[:10])
print(without_mask_fnames[:10])
# Out:
# ['augmented_image_135.jpg', '235-with-mask.jpg', 'IMG_052.jpg', 'augmented_image_87.jpg', 'IMG_012.jpg', '350-with-mask.jpg', '114-with-mask.jpg', 'asian_mask189.jpg', 'asian_mask91.jpg', 'asian_mask240.jpg']
# ['augmented_image_135.jpg', 'gettyimages-915227284-1024x1024.jpg', 'IMG_052.jpg', '144.jpg', 'augmented_image_87.jpg', 'IMG_012.jpg', 'otro (86).jpg', '92.jpg', '428.jpg', '349.jpg']

# %% [markdown]
# Recuento del conjunto de datos

# %%
print('Imagenes con mascara ', len(os.listdir(with_mask_dir)))
print('Imagenes sin mascara ', len(os.listdir(without_mask_dir)))
# Out:
# Imagenes con mascara  1336
# Imagenes sin mascara  1266

# %% [markdown]
# Visualizar algunas de las imagenes del conjunto de datos

# %%
# %matplotlib inline

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# Parámetros para nuestro gráfico; emitiremos imágenes en una configuración 4x4
nrows = 4
ncols = 4

pic_index = 0 # Índice para iterar sobre imágenes

# %%
# Configure matplotlib fig y ajústelo a fotos de 4x4
fig = plt.gcf()
fig.set_size_inches(ncols*4, nrows*4)

pic_index+=8

next_with_mask_pix = [os.path.join(with_mask_dir, fname) 
                for fname in with_mask_fnames[ pic_index-8:pic_index] 
               ]

next_without_mask_pix = [os.path.join(without_mask_dir, fname) 
                for fname in without_mask_fnames[ pic_index-8:pic_index]
               ]

for i, img_path in enumerate(next_with_mask_pix+next_without_mask_pix):
  # Configurar subtrama; los índices de la subparcela comienzan en 1
  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off') # No mostrar ejes (o líneas de cuadrícula)

  img = mpimg.imread(img_path)
  plt.imshow(img)

plt.show()

# %% [markdown]
# # **Modelo propuesto**

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
print(tf.__version__)
# Out:
# 2.4.0

# %% [markdown]
# ## Modelo con el optimizador que implementa el algoritmo RMSprop

# %% [markdown]
# Se formula la secuencia del modelo

# %%
model1 = tf.keras.models.Sequential([
    # Tenga en cuenta que la forma de entrada es el tamaño deseado de la imagen 150x150 con 3 bytes de color
    # Primeria convolución
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    # Segunda convolución
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # Tercera convolución
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # Cuarta convolución
    #tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    #tf.keras.layers.MaxPooling2D(2,2),
    # Quinta convolución
    #tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    #tf.keras.layers.MaxPooling2D(2,2),
    # Aplanar los resultados para incorporarlos a un DNN
    tf.keras.layers.Flatten(),
    # 512 capa oculta de neuronas
    tf.keras.layers.Dense(512, activation='relu'),
    # Solo 1 neurona de salida. Contendrá un valor de 0-1 donde 0 para 1 clase ('Tiene mascarilla') y 1 para la otra ('No tiene mascarilla)
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %% [markdown]
# Sumario del modelo

# %%
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 148, 148, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 74, 74, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 72, 72, 32)        4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 36, 36, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 34, 34, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 17, 17, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 18496)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               9470464
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 9,494,561
# Trainable params: 9,494,561
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Se establece el optimizador y función de perdida

# %%
from tensorflow.keras.optimizers import RMSprop

model1.compile(optimizer = RMSprop(lr=0.001), 
              loss = 'binary_crossentropy', 
              metrics = ['accuracy'])

# %% [markdown]
# Preprocesamiento de imagen para el conjunto de datos

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Todas las imágenes serán reescaladas por 1./255.

datagen = ImageDataGenerator(rescale=1./255,
                             shear_range=0.2,
                             zoom_range=0.2,
                             horizontal_flip=True,
                             validation_split=0.15)

# --------------------
# Imágenes de entrenamiento de flujo en lotes de 20 usando el generador train_datagen
# --------------------
train_generator = datagen.flow_from_directory(data_dir,
                                              batch_size=20,
                                              class_mode='binary',
                                              target_size=(150, 150),
                                              subset='training')     
# --------------------
# Imágenes de validación de flujo en lotes de 20 usando el generador train_datagen
# --------------------
validation_generator =  datagen.flow_from_directory(data_dir,
                                                    batch_size=20,
                                                    class_mode='binary',
                                                    target_size=(150, 150),
                                                    subset='validation')
# Out:
# Found 2213 images belonging to 2 classes.
# Found 389 images belonging to 2 classes.

# %% [markdown]
# Defina una Callback class que detiene el entrenamiento una vez que la precisión alcanza el 99%

# %%
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('val_accuracy') >= 0.98 and logs.get('accuracy') >= 0.999):
      print("\n¡Alcanzó el 99.9% de precisión, cancelando el entrenamiento!")
      self.model.stop_training = True#

# %% [markdown]
# Entrenamiento del modelo

# %%
callbacks = myCallback()
history = model1.fit(train_generator,
                    validation_data=validation_generator,
                    steps_per_epoch=train_generator.samples // 20,
                    epochs=50,
                    validation_steps=validation_generator.samples // 20,
                    callbacks=[callbacks])
# Out:
# Epoch 1/50
# 110/110 [==============================] - 31s 220ms/step - loss: 0.7076 - accuracy: 0.7316 - val_loss: 0.1296 - val_accuracy: 0.9684
# Epoch 2/50
# 110/110 [==============================] - 24s 217ms/step - loss: 0.2664 - accuracy: 0.9001 - val_loss: 0.0772 - val_accuracy: 0.9789
# Epoch 3/50
# 110/110 [==============================] - 24s 217ms/step - loss: 0.2208 - accuracy: 0.9237 - val_loss: 0.0758 - val_accuracy: 0.9789
# Epoch 4/50
# 110/110 [==============================] - 24s 219ms/step - loss: 0.1749 - accuracy: 0.9386 - val_loss: 0.1053 - val_accuracy: 0.9579
# Epoch 5/50
# 110/110 [==============================] - 24s 218ms/step - loss: 0.1678 - accuracy: 0.9475 - val_loss: 0.0401 - val_accuracy: 0.9789
# Epoch 6/50
# 110/110 [==============================] - 24s 218ms/step - loss: 0.1438 - accuracy: 0.9488 - val_loss: 0.0372 - val_accuracy: 0.9816
# Epoch 7/50
# 110/110 [==============================] - 24s 215ms/step - loss: 0.1252 - accuracy: 0.9535 - val_loss: 0.0668 - val_accuracy: 0.9684
# Epoch 8/50
# 110/110 [==============================] - 24s 217ms/step - loss: 0.1247 - accuracy: 0.9502 - val_loss: 0.0494 - val_accuracy: 0.9842
# Epoch 9/50
# 110/110 [==============================] - 24s 218ms/step - loss: 0.1399 - accuracy: 0.9551 - val_loss: 0.0637 - val_accuracy: 0.9737
# Epoch 10/50
# 110/110 [==============================] - 24s 217ms/step - loss: 0.1060 - accuracy: 0.9635 - val_loss: 0.0397 - val_accuracy: 0.9789
# Epoch 11/50
# 110/110 [==============================] - 24s 216ms/step - loss: 0.0783 - accuracy: 0.9732 - val_loss: 0.1971 - val_accuracy: 0.9368
# Epoch 12/50
# 110/110 [==============================] - 24s 218ms/step - loss: 0.0884 - accuracy: 0.9675 - val_loss: 0.0220 - val_accuracy: 0.9921
# Epoch 13/50
# 110/110 [==============================] - 24s 215ms/step - loss: 0.0836 - accuracy: 0.9736 - val_loss: 0.1379 - val_accuracy: 0.9579
# Epoch 14/50
# 110/110 [==============================] - 24s 217ms/step - loss: 0.0791 - accuracy: 0.9721 - val_loss: 0.0949 - val_accuracy: 0.9737
# Epoch 15/50
# 110/110 [==============================] - 24s 218ms/step - loss: 0.0856 - accuracy: 0.9699 - val_loss: 0.0591 - val_accuracy: 0.9816
# Epoch 16/50
# 110/110 [==============================] - 24s 216ms/step - loss: 0.0885 - accuracy: 0.9710 - val_loss: 0.1375 - val_accuracy: 0.9658
# Epoch 17/50
# 110/110 [==============================] - 24s 215ms/step - loss: 0.0724 - accuracy: 0.9737 - val_loss: 0.1867 - val_accuracy: 0.9579
# Epoch 18/50
# 110/110 [==============================] - 24s 215ms/step - loss: 0.0916 - accuracy: 0.9703 - val_loss: 0.1111 - val_accuracy: 0.9658
# Epoch 19/50
# 110/110 [==============================] - 24s 217ms/step - loss: 0.0710 - accuracy: 0.9758 - val_loss: 0.0471 - val_accuracy: 0.9789
# Epoch 20/50
# 110/110 [==============================] - 24s 215ms/step - loss: 0.0770 - accuracy: 0.9810 - val_loss: 0.0575 - val_accuracy: 0.9816
# Epoch 21/50
# 110/110 [==============================] - 24s 213ms/step - loss: 0.0433 - accuracy: 0.9825 - val_loss: 0.0789 - val_accuracy: 0.9868
# Epoch 22/50
# 110/110 [==============================] - 24s 217ms/step - loss: 0.0633 - accuracy: 0.9824 - val_loss: 0.0907 - val_accuracy: 0.9684
# Epoch 23/50
# 110/110 [==============================] - 24s 215ms/step - loss: 0.0399 - accuracy: 0.9878 - val_loss: 0.0880 - val_accuracy: 0.9816
# Epoch 24/50
# 110/110 [==============================] - 23s 211ms/step - loss: 0.0413 - accuracy: 0.9864 - val_loss: 0.0861 - val_accuracy: 0.9816
# Epoch 25/50
# 110/110 [==============================] - 23s 212ms/step - loss: 0.0529 - accuracy: 0.9816 - val_loss: 0.0522 - val_accuracy: 0.9868
# Epoch 26/50
# 110/110 [==============================] - 23s 206ms/step - loss: 0.0331 - accuracy: 0.9893 - val_loss: 0.0779 - val_accuracy: 0.9737
# Epoch 27/50
# 110/110 [==============================] - 22s 204ms/step - loss: 0.0377 - accuracy: 0.9874 - val_loss: 0.0588 - val_accuracy: 0.9842
# Epoch 28/50
# 110/110 [==============================] - 22s 203ms/step - loss: 0.0474 - accuracy: 0.9880 - val_loss: 0.0212 - val_accuracy: 0.9921
# Epoch 29/50
# 110/110 [==============================] - 22s 203ms/step - loss: 0.0563 - accuracy: 0.9846 - val_loss: 0.0260 - val_accuracy: 0.9947
# Epoch 30/50
# 110/110 [==============================] - 22s 199ms/step - loss: 0.0460 - accuracy: 0.9847 - val_loss: 0.0389 - val_accuracy: 0.9868
# Epoch 31/50
# 110/110 [==============================] - 22s 199ms/step - loss: 0.0394 - accuracy: 0.9838 - val_loss: 0.0932 - val_accuracy: 0.9868
# Epoch 32/50
# 110/110 [==============================] - 22s 199ms/step - loss: 0.0586 - accuracy: 0.9860 - val_loss: 0.2745 - val_accuracy: 0.9632
# Epoch 33/50
# 110/110 [==============================] - 22s 202ms/step - loss: 0.0560 - accuracy: 0.9852 - val_loss: 0.0721 - val_accuracy: 0.9868
# Epoch 34/50
# 110/110 [==============================] - 22s 198ms/step - loss: 0.0411 - accuracy: 0.9851 - val_loss: 0.1045 - val_accuracy: 0.9816
# Epoch 35/50
# 110/110 [==============================] - 22s 198ms/step - loss: 0.0247 - accuracy: 0.9898 - val_loss: 0.1753 - val_accuracy: 0.9684
# Epoch 36/50
# 110/110 [==============================] - 22s 200ms/step - loss: 0.0401 - accuracy: 0.9883 - val_loss: 0.1013 - val_accuracy: 0.9842
# Epoch 37/50
# 110/110 [==============================] - 22s 198ms/step - loss: 0.0566 - accuracy: 0.9836 - val_loss: 0.0693 - val_accuracy: 0.9868
# Epoch 38/50
# 110/110 [==============================] - 22s 197ms/step - loss: 0.0491 - accuracy: 0.9835 - val_loss: 0.1345 - val_accuracy: 0.9789
# Epoch 39/50
# 110/110 [==============================] - 22s 198ms/step - loss: 0.0293 - accuracy: 0.9935 - val_loss: 0.1553 - val_accuracy: 0.9763
# Epoch 40/50
# 110/110 [==============================] - 22s 199ms/step - loss: 0.0576 - accuracy: 0.9907 - val_loss: 0.0989 - val_accuracy: 0.9921
# Epoch 41/50
# 110/110 [==============================] - 22s 198ms/step - loss: 0.0460 - accuracy: 0.9876 - val_loss: 0.0807 - val_accuracy: 0.9789
# Epoch 42/50
# 110/110 [==============================] - 22s 198ms/step - loss: 0.0310 - accuracy: 0.9909 - val_loss: 0.0354 - val_accuracy: 0.9868
# Epoch 43/50
# 110/110 [==============================] - 22s 198ms/step - loss: 0.0217 - accuracy: 0.9933 - val_loss: 0.2803 - val_accuracy: 0.9605
# Epoch 44/50
# 110/110 [==============================] - 22s 198ms/step - loss: 0.0663 - accuracy: 0.9870 - val_loss: 0.0910 - val_accuracy: 0.9737
# Epoch 45/50
# 110/110 [==============================] - 22s 197ms/step - loss: 0.0286 - accuracy: 0.9939 - val_loss: 0.0836 - val_accuracy: 0.9789
# Epoch 46/50
# 110/110 [==============================] - 22s 198ms/step - loss: 0.0358 - accuracy: 0.9898 - val_loss: 0.0613 - val_accuracy: 0.9895
# Epoch 47/50
# 110/110 [==============================] - 22s 202ms/step - loss: 0.0140 - accuracy: 0.9971 - val_loss: 0.2149 - val_accuracy: 0.9737
# Epoch 48/50
# 110/110 [==============================] - 22s 199ms/step - loss: 0.0189 - accuracy: 0.9971 - val_loss: 0.0885 - val_accuracy: 0.9868
# Epoch 49/50
# 110/110 [==============================] - 22s 199ms/step - loss: 0.0499 - accuracy: 0.9894 - val_loss: 0.0499 - val_accuracy: 0.9947
# Epoch 50/50
# 110/110 [==============================] - 22s 199ms/step - loss: 0.0300 - accuracy: 0.9933 - val_loss: 0.0836 - val_accuracy: 0.9842

# %% [markdown]
# Rendimiento del modelo

# %%
#-----------------------------------------------------------
# Recupere una lista de resultados de la lista de conjuntos de datos de 
# entrenamiento y prueba para cada época de entrenamiento
#-----------------------------------------------------------
acc      = history.history['accuracy']
val_acc  = history.history['val_accuracy']
loss     = history.history['loss']
val_loss = history.history['val_loss']

epochs   = range(len(acc)) # Obtener número de épocas

#------------------------------------------------
# Trazar la precisión del entrenamiento y la validación por época
#------------------------------------------------
plt.plot  ( epochs, acc )
plt.plot  ( epochs, val_acc )
plt.title ('Precisión de entrenamiento y validación')
plt.figure()

#------------------------------------------------
# Trazar pérdida de validación y entrenamiento por época
#------------------------------------------------
plt.plot  ( epochs,     loss )
plt.plot  ( epochs, val_loss )
plt.title ('Pérdida de entrenamiento y validación')
# Out:
# Text(0.5, 1.0, 'Pérdida de entrenamiento y validación')

# %% [markdown]
# Prueba con imagenes fuera del conjunto de datos

# %%
import numpy as np

from google.colab import files
from keras.preprocessing import image

uploaded=files.upload()

for fn in uploaded.keys():
 
  # predicting images
  path='/content/' + fn
  img=image.load_img(path, target_size=(150, 150))
  
  x=image.img_to_array(img)
  x=np.expand_dims(x, axis=0)
  images = np.vstack([x])
  
  classes = model2.predict(images, batch_size=20)
  
  print(classes[0])
  
  if classes[0]>0:
    print(fn + " No tiene mascarilla")   
  else:
    print(fn + " Tiene mascarilla")
# Out:
#      <input type="file" id="files-fd7c969e-ff58-41fa-bde3-2cf5d24d99d7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fd7c969e-ff58-41fa-bde3-2cf5d24d99d7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %% [markdown]
# ## Modelo con el optimizador Adam

# %% [markdown]
# Se formula la secuencia del modelo

# %%
model2 = tf.keras.models.Sequential([
    # Tenga en cuenta que la forma de entrada es el tamaño deseado de la imagen 150x150 con 3 bytes de color
    # Primeria convolución
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    # Segunda convolución
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # Tercera convolución
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # Cuarta convolución
    #tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    #tf.keras.layers.MaxPooling2D(2,2),
    # Quinta convolución
    #tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    #tf.keras.layers.MaxPooling2D(2,2),
    # Aplanar los resultados para incorporarlos a un DNN
    tf.keras.layers.Flatten(),
    # 512 capa oculta de neuronas
    tf.keras.layers.Dense(512, activation='relu'),
    # Solo 1 neurona de salida. Contendrá un valor de 0-1 donde 0 para 1 clase ('Tiene mascarilla') y 1 para la otra ('No tiene mascarilla)
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %% [markdown]
# Sumario del modelo

# %%
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 148, 148, 16)      448
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 74, 74, 16)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 72, 72, 32)        4640
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 36, 36, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 34, 34, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 17, 17, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18496)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               9470464
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 9,494,561
# Trainable params: 9,494,561
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Se establece el optimizador y función de perdida

# %%
from tensorflow.keras.optimizers import Adam

model2.compile(optimizer= 'adam',
              loss='binary_crossentropy',
              metrics = ['accuracy'])

# %% [markdown]
# Preprocesamiento de imagen para el conjunto de datos

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Todas las imágenes serán reescaladas por 1./255.

datagen = ImageDataGenerator(rescale=1./255,
                             shear_range=0.2,
                             zoom_range=0.2,
                             horizontal_flip=True,
                             validation_split=0.15)

# --------------------
# Imágenes de entrenamiento de flujo en lotes de 20 usando el generador train_datagen
# --------------------
train_generator = datagen.flow_from_directory(data_dir,
                                              batch_size=20,
                                              class_mode='binary',
                                              target_size=(150, 150),
                                              subset='training')     
# --------------------
# Imágenes de validación de flujo en lotes de 20 usando el generador train_datagen
# --------------------
validation_generator =  datagen.flow_from_directory(data_dir,
                                                    batch_size=20,
                                                    class_mode='binary',
                                                    target_size=(150, 150),
                                                    subset='validation')
# Out:
# Found 2213 images belonging to 2 classes.
# Found 389 images belonging to 2 classes.

# %% [markdown]
# Defina una Callback class que detiene el entrenamiento una vez que la precisión alcanza el 98.5%

# %%
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('val_accuracy') >= 0.99 and logs.get('accuracy') >= 0.99):
      print("\n¡Alcanzó el 98.5% de precisión, cancelando el entrenamiento!")
      self.model.stop_training = True

# %% [markdown]
# Entrenamiento del modelo

# %%
callbacks = myCallback()
history = model2.fit(train_generator,
                    validation_data=validation_generator,
                    steps_per_epoch=train_generator.samples // 20,
                    epochs=50,
                    validation_steps=validation_generator.samples // 20,
                    callbacks=[callbacks])
# Out:
# Epoch 1/50
# 110/110 [==============================] - 22s 200ms/step - loss: 0.6958 - accuracy: 0.6541 - val_loss: 0.1304 - val_accuracy: 0.9658
# Epoch 2/50
# 110/110 [==============================] - 22s 199ms/step - loss: 0.2552 - accuracy: 0.9030 - val_loss: 0.1018 - val_accuracy: 0.9711
# Epoch 3/50
# 110/110 [==============================] - 22s 196ms/step - loss: 0.2153 - accuracy: 0.9222 - val_loss: 0.1117 - val_accuracy: 0.9632
# Epoch 4/50
# 110/110 [==============================] - 22s 197ms/step - loss: 0.2023 - accuracy: 0.9321 - val_loss: 0.1039 - val_accuracy: 0.9737
# Epoch 5/50
# 110/110 [==============================] - 22s 198ms/step - loss: 0.1427 - accuracy: 0.9432 - val_loss: 0.0688 - val_accuracy: 0.9842
# Epoch 6/50
# 110/110 [==============================] - 22s 197ms/step - loss: 0.1969 - accuracy: 0.9244 - val_loss: 0.1108 - val_accuracy: 0.9553
# Epoch 7/50
# 110/110 [==============================] - 22s 197ms/step - loss: 0.1881 - accuracy: 0.9251 - val_loss: 0.0641 - val_accuracy: 0.9737
# Epoch 8/50
# 110/110 [==============================] - 22s 196ms/step - loss: 0.1360 - accuracy: 0.9500 - val_loss: 0.0960 - val_accuracy: 0.9553
# Epoch 9/50
# 110/110 [==============================] - 22s 198ms/step - loss: 0.1645 - accuracy: 0.9412 - val_loss: 0.0654 - val_accuracy: 0.9684
# Epoch 10/50
# 110/110 [==============================] - 22s 198ms/step - loss: 0.0965 - accuracy: 0.9592 - val_loss: 0.1170 - val_accuracy: 0.9395
# Epoch 11/50
# 110/110 [==============================] - 22s 198ms/step - loss: 0.1095 - accuracy: 0.9583 - val_loss: 0.0597 - val_accuracy: 0.9737
# Epoch 12/50
# 110/110 [==============================] - 22s 197ms/step - loss: 0.1047 - accuracy: 0.9587 - val_loss: 0.1063 - val_accuracy: 0.9553
# Epoch 13/50
# 110/110 [==============================] - 22s 198ms/step - loss: 0.1052 - accuracy: 0.9575 - val_loss: 0.0296 - val_accuracy: 0.9842
# Epoch 14/50
# 110/110 [==============================] - 22s 196ms/step - loss: 0.0823 - accuracy: 0.9727 - val_loss: 0.1136 - val_accuracy: 0.9553
# Epoch 15/50
# 110/110 [==============================] - 22s 197ms/step - loss: 0.1106 - accuracy: 0.9604 - val_loss: 0.0421 - val_accuracy: 0.9895
# Epoch 16/50
# 110/110 [==============================] - 22s 196ms/step - loss: 0.0723 - accuracy: 0.9773 - val_loss: 0.0270 - val_accuracy: 0.9895
# Epoch 17/50
# 110/110 [==============================] - 22s 197ms/step - loss: 0.0602 - accuracy: 0.9784 - val_loss: 0.0359 - val_accuracy: 0.9842
# Epoch 18/50
# 110/110 [==============================] - 22s 196ms/step - loss: 0.0430 - accuracy: 0.9823 - val_loss: 0.0418 - val_accuracy: 0.9816
# Epoch 19/50
# 110/110 [==============================] - 22s 196ms/step - loss: 0.0500 - accuracy: 0.9841 - val_loss: 0.0483 - val_accuracy: 0.9789
# Epoch 20/50
# 110/110 [==============================] - 22s 197ms/step - loss: 0.0383 - accuracy: 0.9858 - val_loss: 0.0529 - val_accuracy: 0.9789
# Epoch 21/50
# 110/110 [==============================] - 22s 194ms/step - loss: 0.0306 - accuracy: 0.9902 - val_loss: 0.0799 - val_accuracy: 0.9763
# Epoch 22/50
# 110/110 [==============================] - 22s 196ms/step - loss: 0.0360 - accuracy: 0.9876 - val_loss: 0.0875 - val_accuracy: 0.9711
# Epoch 23/50
# 110/110 [==============================] - 22s 199ms/step - loss: 0.0355 - accuracy: 0.9864 - val_loss: 0.0656 - val_accuracy: 0.9737
# Epoch 24/50
# 110/110 [==============================] - 22s 198ms/step - loss: 0.0348 - accuracy: 0.9884 - val_loss: 0.0682 - val_accuracy: 0.9711
# Epoch 25/50
# 110/110 [==============================] - 22s 196ms/step - loss: 0.0359 - accuracy: 0.9872 - val_loss: 0.0822 - val_accuracy: 0.9737
# Epoch 26/50
# 110/110 [==============================] - 22s 196ms/step - loss: 0.0221 - accuracy: 0.9950 - val_loss: 0.0415 - val_accuracy: 0.9737
# Epoch 27/50
# 110/110 [==============================] - 22s 197ms/step - loss: 0.0305 - accuracy: 0.9898 - val_loss: 0.0487 - val_accuracy: 0.9737
# Epoch 28/50
# 110/110 [==============================] - 22s 197ms/step - loss: 0.0454 - accuracy: 0.9839 - val_loss: 0.0413 - val_accuracy: 0.9816
# Epoch 29/50
# 110/110 [==============================] - 22s 196ms/step - loss: 0.0147 - accuracy: 0.9946 - val_loss: 0.0707 - val_accuracy: 0.9711
# Epoch 30/50
# 110/110 [==============================] - 22s 197ms/step - loss: 0.0220 - accuracy: 0.9935 - val_loss: 0.0402 - val_accuracy: 0.9842
# Epoch 31/50
# 110/110 [==============================] - 22s 198ms/step - loss: 0.0134 - accuracy: 0.9944 - val_loss: 0.1350 - val_accuracy: 0.9579
# Epoch 32/50
# 110/110 [==============================] - 22s 198ms/step - loss: 0.0496 - accuracy: 0.9843 - val_loss: 0.0401 - val_accuracy: 0.9868
# Epoch 33/50
# 110/110 [==============================] - 22s 198ms/step - loss: 0.0249 - accuracy: 0.9881 - val_loss: 0.0603 - val_accuracy: 0.9763
# Epoch 34/50
# 110/110 [==============================] - 22s 197ms/step - loss: 0.0092 - accuracy: 0.9971 - val_loss: 0.0549 - val_accuracy: 0.9842
# Epoch 35/50
# 110/110 [==============================] - 22s 198ms/step - loss: 0.0141 - accuracy: 0.9955 - val_loss: 0.0999 - val_accuracy: 0.9684
# Epoch 36/50
# 110/110 [==============================] - 22s 198ms/step - loss: 0.0691 - accuracy: 0.9714 - val_loss: 0.0752 - val_accuracy: 0.9789
# Epoch 37/50
# 110/110 [==============================] - 22s 199ms/step - loss: 0.0188 - accuracy: 0.9939 - val_loss: 0.1003 - val_accuracy: 0.9763
# Epoch 38/50
# 110/110 [==============================] - 22s 198ms/step - loss: 0.0235 - accuracy: 0.9935 - val_loss: 0.1093 - val_accuracy: 0.9684
# Epoch 39/50
# 110/110 [==============================] - 22s 197ms/step - loss: 0.0104 - accuracy: 0.9983 - val_loss: 0.0751 - val_accuracy: 0.9789
# Epoch 40/50
# 110/110 [==============================] - 22s 196ms/step - loss: 0.0128 - accuracy: 0.9955 - val_loss: 0.0704 - val_accuracy: 0.9684
# Epoch 41/50
# 110/110 [==============================] - 21s 196ms/step - loss: 0.0241 - accuracy: 0.9924 - val_loss: 0.0494 - val_accuracy: 0.9789
# Epoch 42/50
# 110/110 [==============================] - 22s 196ms/step - loss: 0.0120 - accuracy: 0.9945 - val_loss: 0.0820 - val_accuracy: 0.9763
# Epoch 43/50
# 110/110 [==============================] - 22s 197ms/step - loss: 0.0081 - accuracy: 0.9980 - val_loss: 0.0813 - val_accuracy: 0.9816
# Epoch 44/50
# 110/110 [==============================] - 21s 196ms/step - loss: 0.0100 - accuracy: 0.9978 - val_loss: 0.0901 - val_accuracy: 0.9684
# Epoch 45/50
# 110/110 [==============================] - 22s 196ms/step - loss: 0.0104 - accuracy: 0.9977 - val_loss: 0.0652 - val_accuracy: 0.9895
# Epoch 46/50
# 110/110 [==============================] - 22s 196ms/step - loss: 0.0089 - accuracy: 0.9984 - val_loss: 0.0619 - val_accuracy: 0.9816
# Epoch 47/50
# 110/110 [==============================] - 22s 195ms/step - loss: 0.0030 - accuracy: 0.9989 - val_loss: 0.0991 - val_accuracy: 0.9842
# Epoch 48/50
# 110/110 [==============================] - 22s 196ms/step - loss: 0.0046 - accuracy: 0.9984 - val_loss: 0.0763 - val_accuracy: 0.9789
# Epoch 49/50
# 110/110 [==============================] - 21s 195ms/step - loss: 0.0107 - accuracy: 0.9948 - val_loss: 0.1514 - val_accuracy: 0.9658
# Epoch 50/50
# 110/110 [==============================] - 22s 196ms/step - loss: 0.0266 - accuracy: 0.9892 - val_loss: 0.0652 - val_accuracy: 0.9816

# %% [markdown]
# Rendimiento del modelo

# %%
#-----------------------------------------------------------
# Recupere una lista de resultados de la lista de conjuntos de datos de 
# entrenamiento y prueba para cada época de entrenamiento
#-----------------------------------------------------------
acc      = history.history['accuracy']
val_acc  = history.history['val_accuracy']
loss     = history.history['loss']
val_loss = history.history['val_loss']

epochs   = range(len(acc)) # Obtener número de épocas

#------------------------------------------------
# Trazar la precisión del entrenamiento y la validación por época
#------------------------------------------------
plt.plot  ( epochs, acc )
plt.plot  ( epochs, val_acc )
plt.title ('Precisión de entrenamiento y validación')
plt.figure()

#------------------------------------------------
# Trazar pérdida de validación y entrenamiento por época
#------------------------------------------------
plt.plot  ( epochs,     loss )
plt.plot  ( epochs, val_loss )
plt.title ('Pérdida de entrenamiento y validación')
# Out:
# Text(0.5, 1.0, 'Pérdida de entrenamiento y validación')

# %% [markdown]
# Prueba con imagenes fuera del conjunto de datos

# %%
import numpy as np

from google.colab import files
from keras.preprocessing import image

uploaded=files.upload()

for fn in uploaded.keys():
 
  # predicting images
  path='/content/' + fn
  img=image.load_img(path, target_size=(150, 150))
  
  x=image.img_to_array(img)
  x=np.expand_dims(x, axis=0)
  images = np.vstack([x])
  
  classes = model2.predict(images, batch_size=20)
  
  print(classes[0])
  
  if classes[0]>0:
    print(fn + " No tiene mascarilla")   
  else:
    print(fn + " Tiene mascarilla")
# Out:
#      <input type="file" id="files-f0ab997b-1415-49fd-bc01-b90c3aeba671" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f0ab997b-1415-49fd-bc01-b90c3aeba671">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %% [markdown]
# # Convertir el modelo a TFLite

# %%
converter_1 = tf.lite.TFLiteConverter.from_keras_model(model1)
tflite_model_1 = converter_1.convert()
open("model_1.tflite","wb").write(tflite_model_1)
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpoqdu7kks/assets
# 37981968

# %%
converter_2 = tf.lite.TFLiteConverter.from_keras_model(model2)
tflite_model_2 = converter_2.convert()
open("model_2.tflite","wb").write(tflite_model_2)
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpmlckx4uq/assets
# INFO:tensorflow:Assets written to: /tmp/tmpmlckx4uq/assets
# 37982072
